# %%
import pandas as pd

# %%
df=pd.read_csv('insurance_data.csv')

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df.age,df.bought_insurance)

# %%
from sklearn.linear_model import LinearRegression as reg

# %%
model=reg()
model.fit(df[['age']],df.bought_insurance)
model
# Out:
# LinearRegression()

# %%
plt.plot(df.age,model.predict(df[['age']]),color='r')
plt.scatter(df.age,df.bought_insurance,marker='+',color='violet')

# %%
df.shape
# Out:
# (27, 2)

# %%
from sklearn.model_selection import train_test_split

# %%
X=df[['age']]
X
# Out:
#     age
# 0    22
# 1    25
# 2    47
# 3    52
# 4    46
# 5    56
# 6    55
# 7    60
# 8    62
# 9    61
# 10   18
# 11   28
# 12   27
# 13   29
# 14   49
# 15   55
# 16   25
# 17   58
# 18   19
# 19   18
# 20   21
# 21   26
# 22   40
# 23   45
# 24   50
# 25   54
# 26   23

# %%
y=df.bought_insurance
y
# Out:
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    0
# 11    0
# 12    0
# 13    0
# 14    1
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    1
# 25    1
# 26    0
# Name: bought_insurance, dtype: int64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,y,train_size=0.9)

# %%
xtrain
# Out:
#     age
# 24   50
# 9    61
# 25   54
# 4    46
# 18   19
# 22   40
# 10   18
# 20   21
# 14   49
# 6    55
# 7    60
# 16   25
# 2    47
# 17   58
# 26   23
# 11   28
# 8    62
# 12   27
# 13   29
# 21   26
# 1    25
# 5    56
# 19   18
# 15   55

# %%
len(xtrain),len(xtest),len(ytrain),len(ytest)
# Out:
# (24, 3, 24, 3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
model.predict(xtest)
# Out:
# array([0, 1, 1], dtype=int64)

# %%
model.score(xtest,ytest),model.score(xtrain,ytrain)
# Out:
# (0.6666666666666666, 0.9166666666666666)

# %%
model.predict_proba(xtest)
# Out:
# array([[0.91182336, 0.08817664],
#        [0.2240267 , 0.7759733 ],
#        [0.08855168, 0.91144832]])

# %%
model.predict([[75]])
# Out:
# D:\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
plt.scatter(df['age'],df['bought_insurance'])
model.fit(df[['age']],df.bought_insurance)
plt.plot(df.age,model.predict(X))
