# %%
from sklearn import linear_model as lm

# %%
import pandas as pd
import numpy as np
import math as m
from word2number import w2n as wn

# %%
d=pd.read_csv('hiring.csv')

# %%
d
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
d.experience=d.experience.fillna('zero')

# %%
d.experience
# Out:
# 0      zero
# 1      zero
# 2      five
# 3       two
# 4     seven
# 5     three
# 6       ten
# 7    eleven
# Name: experience, dtype: object

# %%
d.experience=d.experience.apply(wn.word_to_num)

# %%
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    NaN                           7      72000
# 7          11                    7.0                           8      80000

# %%
d['test_score(out of 10)']=d['test_score(out of 10)'].fillna(m.floor(d['test_score(out of 10)'].mean()))

# %%
m.floor(d['test_score(out of 10)'].mean())
# Out:
# 7

# %%
d['test_score(out of 10)'].mean()
# Out:
# 7.75

# %%
d
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0           0                    8.0                           9      50000
# 1           0                    8.0                           6      45000
# 2           5                    6.0                           7      60000
# 3           2                   10.0                          10      65000
# 4           7                    9.0                           6      70000
# 5           3                    7.0                          10      62000
# 6          10                    7.0                           7      72000
# 7          11                    7.0                           8      80000

# %%
reg=lm.LinearRegression()

# %%
reg.fit(d[['experience','test_score(out of 10)','interview_score(out of 10)']],d['salary($)'])
# Out:
# LinearRegression()

# %%
reg.predict([[2,9,6]])[0]
# Out:
# D:\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 53713.86677124005

# %%
reg.predict([[12,10,10]])[0]
# Out:
# D:\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 93747.79628650834

# %%
reg.predict([[11,7,8]])[0]
# Out:
# D:\ANACONDA\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 79866.63483998568
